# %%
from random import sample, randint

def get_rec_info():
    # esta funcion retorna una lista con tuplas de la frecuencia y la frase asociada y
    # tambien una lista de prefijos asociada, para la cual deberian poder dar una 
    # recomendacion en menos de 1.5 segundos (en colab).
    # es importante que el archivo 'info_recomendaciones.txt' este el la misma carpeta que
    # el script. En colab se pueden subir archivos con el navegador en la izquierda. 

    with open('info_recomendaciones.txt', 'r') as file:
        ret = [(int(line[0]), ' '.join(line[2:])) for line in [l.strip().split() for l in file]]
    prefijos = sample(list(set(pal[:randint(1,9*len(pal)//10)] for pal in [p[1] for p in ret])), 3000)
    return ret, prefijos

frecuencias, prefijos = get_rec_info()

print(frecuencias, prefijos)
# Out:
# [(10, 'been able to respond to'), (8, 'science and mathematics educational gains'), (10, 'we now know to be'), (9, 'took a few steps into'), (17, 'to do with health care'), (14, 'and it does not matter'), (48, 'had something to say about'), (6, 'at the united nations was'), (11, 'of the first and third'), (6, 'to cut social security and'), (10, 'may ultimately prove to be'), (7, 'no one had figured out'), (24, 'the demand side of the'), (8, 'is by no means inevitable'), (7, 'to study the work of'), (8, 'far side of the fence'), (6, 'are significantly different from zero'), (7, 'of his eyes and his'), (9, 'a week for the rest'), (8, 'with their own version of'), (10, 'was that he would be'), (12, 'is that it allows us'), (8, 'like to see her again'), (7, 'take a vow of celibacy'), (9, 'to do as part of'), (12, 'to get along well with'), (19, 'a chance to go out'), (8, 'the same kind of thinking'), (21, 'males are more likely to'), (53, 'have a right to have'), (7, 'there is some overlap between'), (9, 'too far in favor of'), (11, 'freshly ground white pepper to'), (6, 'so obvious as to be'), (8, 'as if he too had'), (8, 'would never have anything to'), (12, 'i have seen the future'), (6, 'able to use that information'), (24, 'a return trip to the'), (66, 'a study conducted by the'), (6, 'the country to which they'), (7, 'percent per year during the'), (7, 'a growing problem in the'), (6, 'whose only claim to fame'), (12, 'is going to be effective'), (6, 'the period of the war'), (20, 'for a few minutes while'), (6, 'know a better way to'), (7, 'they are made in the'), (18, 'a woman in front of'), (12, 'oscar for his role in'), (9, 'for some of these things'), (10, 'to do whatever she wanted'), (13, 'looked like someone who had'), (8, 'of the gang of four'), (6, 'question as to whether we'), (15, 'front of the door to'), (7, 'in a recent article for'), (8, 'from the construction of a'), (7, 'the most famous name in'), (7, 'for both of us and'), (7, 'to cut greenhouse gas emissions'), (12, 'more they remain the same'), (8, 'he was dimly aware of'), (8, 'a random sampling of the'), (20, 'journal of college student development'), (7, 'was tired of trying to'), (55, 'you to go back to'), (6, 'received the attention they deserve'), (21, 'the beginning of the campaign'), (16, 'as any of the others'), (12, 'did not want his name'), (24, 'that the environmental protection agency'), (6, 'there was one thing the'), (16, 'what is meant by a'), (8, 'her mother worked as a'), (7, 'back on the witness stand'), (172, 'this was supposed to be'), (11, 'i was involved with the'), (9, 'word to the american people'), (20, 'there is simply not enough'), (11, 'the way to the station'), (6, 'of the report by the'), (16, 'knocks on the door and'), (12, 'off on one of his'), (6, 'was heavily influenced by the'), (17, 'you have only a few'), (6, 'the last days before the'), (6, 'do little to help the'), (9, 'hope is that people will'), (8, 'he may not have had'), (16, 'sitting next to him in'), (37, 'will be a little bit'), (18, 'of the outer solar system'), (11, 'we know for certain is'), (6, 'of those kind of people'), (6, 'is this a good place'), (9, 'so do the rest of'), (10, 'were convicted and sentenced to'), (7, 'account of one of the'), (6, 'not to show their faces'), (19, 'going to come and get'), (7, 'those days there was no'), (13, 'to try to change that'), (8, 'it look as if it'), (42, 'it would come to this'), (7, 'the hands of their enemies'), (11, 'community service society of new'), (6, 'in the two years she'), (8, 'professor of animal science at'), (17, 'will be able to show'), (14, 'the team reported in the'), (16, 'to learn from one another'), (6, 'the material used in the'), (10, 'this city is going to'), (6, 'involved in taking care of'), (6, 'another man in a suit'), (22, 'loosen particles from bottom of'), (10, 'the government of the prc'), (6, 'officials say it would be'), (15, 'as to the effectiveness of'), (21, 'to make sure i h ...
