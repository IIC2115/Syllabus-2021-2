# %%
import Ejemplo

# %%
Ejemplo.Menu().run()
# Out:
#             Menu:
#                 1: Mostrar Post-Its
#                 2: Buscar Post-Its
#                 3: Agregar nuevo Post-It
#                 4: Modificar Post-It existente
#                 5: Salir
#
# Ingrese Opcion: 5
# Gracias por usar nuestro Post-It
